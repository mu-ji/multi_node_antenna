# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pos_angle_list = np.load('angle_0_pos.npz')['arr_0']
neg_angle_list = np.load('angle_0_neg.npz')['arr_0']
print(pos_angle_list)
print(neg_angle_list)

plt.figure()
plt.scatter([0]*len(neg_angle_list), neg_angle_list, color='r')
plt.scatter([0]*len(pos_angle_list), pos_angle_list, color='b')
plt.show()
# Out:
# [-9.28469068e+00  2.41380532e+01  1.85274035e+01 -2.68960971e+01
#  -9.76931520e+00  6.24984732e-02  5.34501843e-01  1.81442231e+01
#   9.99481723e+00 -1.77355211e+01  3.12762929e+00  9.39558477e+00
#  -1.38735257e+01 -6.81827116e+00 -1.94901599e+01  6.28090845e+01
#   1.08163223e+01 -1.01207218e+01 -1.59025771e+01 -6.28324549e+00
#   1.41214507e+01  4.35316612e+00 -2.24415265e+01  7.01277310e+00
#   8.56427891e+00 -2.58339271e+01 -5.50380914e+00 -9.26288567e+00
#   1.36097543e+00  2.31610588e+00 -2.73889908e+01  7.26737147e+00
#  -6.52257547e+00  1.75834748e+01 -1.07795306e+01  7.86195779e+00
#   1.94153469e+00  5.81690825e-01  1.13492169e+01  4.55207129e+00
#  -2.43823957e+01  8.46665731e+00  7.01096637e+00  1.96190195e+01
#  -3.72953638e+00  2.09661298e+00 -2.35051029e+01 -1.75331524e+01
#  -9.58853839e+00  1.94176033e+01 -1.17501717e+01]
# [ -9.28001933  24.14310519  18.53226523 -26.89092847  -9.76463776
#    0.07171898   0.54833309  18.14907374   9.99949849 -17.73068183
# ...
